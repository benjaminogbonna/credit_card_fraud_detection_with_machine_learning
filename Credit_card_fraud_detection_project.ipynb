# %% [markdown]
# # This is a Fraud detection project using Machine Learning

# %% [markdown]
# ## Note Book imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')
import seaborn as sns
import tensorflow as tf

# %% [markdown]
# ## Geting the data

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/My Drive/Colab Notebooks/credit_card_detection_project')

dataframe = pd.read_csv('data/creditcard.csv')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Data exploration

# %%
dataframe.head(10)
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
# 5   2.0 -0.425966  0.960523  1.141109  ...  0.253844  0.081080    3.67      0
# 6   4.0  1.229658  0.141004  0.045371  ...  0.034507  0.005168    4.99      0
# 7   7.0 -0.644269  1.417964  1.074380  ... -1.206921 -1.085339   40.80      0
# 8   7.0 -0.894286  0.286157 -0.113192  ...  0.011747  0.142404   93.20      0
# 9   9.0 -0.338262  1.119593  1.044367  ...  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %%
dataframe.tail(10)
# Out:
#             Time         V1         V2  ...       V28  Amount  Class
# 284797  172782.0  -0.241923   0.712247  ...  0.081265    5.49      0
# 284798  172782.0   0.219529   0.881246  ...  0.215243   24.05      0
# 284799  172783.0  -1.775135  -0.004235  ...  0.130308   79.99      0
# 284800  172784.0   2.039560  -0.175233  ... -0.075071    2.68      0
# 284801  172785.0   0.120316   0.931005  ...  0.068803    2.69      0
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79      0
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88      0
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00      0
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      0
#
# [10 rows x 31 columns]

# %%
dataframe.describe()
# Out:
#                 Time            V1  ...         Amount          Class
# count  284807.000000  2.848070e+05  ...  284807.000000  284807.000000
# mean    94813.859575  3.919560e-15  ...      88.349619       0.001727
# std     47488.145955  1.958696e+00  ...     250.120109       0.041527
# min         0.000000 -5.640751e+01  ...       0.000000       0.000000
# 25%     54201.500000 -9.203734e-01  ...       5.600000       0.000000
# 50%     84692.000000  1.810880e-02  ...      22.000000       0.000000
# 75%    139320.500000  1.315642e+00  ...      77.165000       0.000000
# max    172792.000000  2.454930e+00  ...   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %%
dataframe.Class.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
dataframe.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ## Visualizing our Data

# %%
colors = ["#0101DF", "#DF0101"]

plt.figure(figsize=(8, 6))
sns.countplot(x='Class', data=dataframe, palette=colors)
plt.title('Class Distributions \n 0: Non Fraud      1: Fraud', fontsize=14, color='k')
# Out:
# Text(0.5, 1.0, 'Class Distributions \n 0: Non Fraud      1: Fraud')

# %%
category_names = ['Non Fraud', 'Fraud']
sizes = [dataframe.Class.value_counts()[0], dataframe.Class.value_counts()[1]]

plt.figure(figsize=(10,10))
plt.pie(sizes, labels=category_names, autopct='%1.1f%%', explode=[0, 0.05], textprops={'fontsize': 20})
plt.show()

# %%
fig = plt.figure(figsize=(15, 20))
plt.suptitle('Histograms of Numerical Columns', fontsize=20)
for i in range(dataframe.shape[1]):
    plt.subplot(8, 4, i + 1)
    f = plt.gca()
    f.set_title(dataframe.columns.values[i])

    vals = np.size(dataframe.iloc[:, i].unique())
    if vals >= 100:
        vals = 100                                    # limit our bins to 100 maximum
    
    plt.hist(dataframe.iloc[:, i], bins=vals, color='#3F5D7D')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# %% [markdown]
# ## Checking the distribution of amount

# %%
plt.figure(figsize=(10, 5))
sns.distplot(dataframe.Amount)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Pre-processing: Cleaning the data

# %%
from sklearn.preprocessing import StandardScaler
dataframe['NormalizedAmount'] = StandardScaler().fit_transform(dataframe['Amount'].values.reshape(-1,1))  # Normalize 'Amount' in [-1,+1] range
data = dataframe.drop(['Amount'],axis=1)

# %%
data.head()
# Out:
#    Time        V1        V2  ...       V28  Class  NormalizedAmount
# 0   0.0 -1.359807 -0.072781  ... -0.021053      0          0.244964
# 1   0.0  1.191857  0.266151  ...  0.014724      0         -0.342475
# 2   1.0 -1.358354 -1.340163  ... -0.059752      0          1.160686
# 3   1.0 -0.966272 -0.185226  ...  0.061458      0          0.140534
# 4   2.0 -1.158233  0.877737  ...  0.215153      0         -0.073403
#
# [5 rows x 31 columns]

# %%
data = data.drop(['Time'],axis=1)
data.head()
# Out:
#          V1        V2        V3  ...       V28  Class  NormalizedAmount
# 0 -1.359807 -0.072781  2.536347  ... -0.021053      0          0.244964
# 1  1.191857  0.266151  0.166480  ...  0.014724      0         -0.342475
# 2 -1.358354 -1.340163  1.773209  ... -0.059752      0          1.160686
# 3 -0.966272 -0.185226  1.792993  ...  0.061458      0          0.140534
# 4 -1.158233  0.877737  1.548718  ...  0.215153      0         -0.073403
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Splitting Our data for training and testing

# %%
X = data.iloc[:, data.columns != 'Class']
y = data.iloc[:, data.columns == 'Class']

# %%
X.head()
# Out:
#          V1        V2        V3  ...       V27       V28  NormalizedAmount
# 0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053          0.244964
# 1  1.191857  0.266151  0.166480  ... -0.008983  0.014724         -0.342475
# 2 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752          1.160686
# 3 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458          0.140534
# 4 -1.158233  0.877737  1.548718  ...  0.219422  0.215153         -0.073403
#
# [5 rows x 29 columns]

# %%
y.head()
# Out:
#    Class
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state=42)

# %%
X_train
# Out:
#               V1        V2        V3  ...       V27       V28  NormalizedAmount
# 2557   -2.289565 -0.480260  0.818685  ...  0.392241 -0.147757         -0.349231
# 247823 -0.313717 -4.064342 -3.398445  ... -0.290331  0.110360          4.421605
# 152342 -1.809763 -0.567439  2.265186  ... -0.062385  0.088079         -0.053373
# 103385  1.192319  0.178575  0.141491  ... -0.016956  0.011937         -0.345313
# 8771   -0.963451  0.700311  1.097333  ...  0.349708  0.216207         -0.204061
# ...          ...       ...       ...  ...       ...       ...               ...
# 119879  1.173488  0.100792  0.490512  ... -0.020922  0.003967         -0.345313
# 259178 -0.775981  0.144023 -1.142399  ...  0.066006  0.137056          0.003520
# 131932 -0.146609  0.992946  1.524591  ... -0.121139 -0.196195         -0.337477
# 146867 -2.948638  2.354849 -2.521201  ...  0.496912  0.335822         -0.349231
# 121958  1.233174 -0.784851  0.386784  ...  0.001217  0.038588          0.098554
#
# ...

# %%
# check for input shapes and size

X_train.shape, X_test.shape
# Out:
# ((199364, 29), (85443, 29))

# %%
y_train.shape, y_test.shape
# Out:
# ((199364, 1), (85443, 1))

# %% [markdown]
# # Exploring Different Algorithms

# %% [markdown]
# ## Decision Tree: J48

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree = DecisionTreeClassifier()

# %%
decision_tree.fit(X_train, y_train.values.ravel())
# Out:
# DecisionTreeClassifier()

# %%
y_pred = decision_tree.predict(X_test)

# %% [markdown]
# ## Checking the accuracy of our Model

# %%
decision_tree.score(X_test, y_test)
# Out:
# 0.9990754069964772

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, plot_roc_curve
tree_acc = accuracy_score(y_test, y_pred)
tree_prec = precision_score(y_test, y_pred)
tree_rec = recall_score(y_test, y_pred)
tree_f1 = f1_score(y_test, y_pred)

print('accuracy:%0.4f'%tree_acc,'\tprecision:%0.4f'%tree_prec,'\trecall:%0.4f'%tree_rec,'\tF1-score:%0.4f'%tree_f1)
# Out:
# accuracy:0.9991 	precision:0.6887 	recall:0.7647 	F1-score:0.7247

# %%
print('accuracy:%0.4f'%acc,'\tprecision:%0.4f'%prec,'\trecall:%0.4f'%rec,'\tF1-score:%0.4f'%f1)

# %%
tree_results = pd.DataFrame([['DecisionTree', tree_acc, 1-tree_rec, tree_rec, tree_prec, tree_f1]],
               columns = ['Model', 'Accuracy', 'FalseNegRate', 'Recall', 'Precision', 'F1 Score'])

tree_results
# Out:
#           Model  Accuracy  FalseNegRate    Recall  Precision  F1 Score
# 0  DecisionTree  0.999075      0.235294  0.764706   0.688742  0.724739

# %%
# condusion matrix

from sklearn.metrics import confusion_matrix
conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, square=True, annot=True, cmap='Blues', fmt='d', cbar=False)
plt.title('Confusion matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, -1.340000000000014, 'Predicted label')

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier(n_estimators=100)

# %%
# fit the model

random_forest.fit(X_train, y_train.values.ravel())
# Out:
# RandomForestClassifier()

# %%
y_pred = random_forest.predict(X_test)

# %% [markdown]
# ## Checking the accuracy of our Model

# %%
random_forest.score(X_test,y_test)
# Out:
# 0.9996137776061234

# %%
random_acc = accuracy_score(y_test, y_pred)
random_prec = precision_score(y_test, y_pred)
random_rec = recall_score(y_test, y_pred)
random_f1 = f1_score(y_test, y_pred)

print('accuracy:%0.4f'%random_acc,'\tprecision:%0.4f'%random_prec,'\trecall:%0.4f'%random_rec,'\tF1-score:%0.4f'%random_f1)
# Out:
# accuracy:0.9996 	precision:0.9478 	recall:0.8015 	F1-score:0.8685

# %%
conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, square=True, annot=True, cmap='Blues', fmt='d', cbar=False)
plt.title('Confusion matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, -1.340000000000014, 'Predicted label')

# %% [markdown]
# ## Compare our two models

# %%
random_results = pd.DataFrame([['Random Forest', random_acc, 1-random_rec, random_rec, random_prec, random_f1]],
               columns = ['Model', 'Accuracy', 'FalseNegRate', 'Recall', 'Precision', 'F1 Score'])

model_results = tree_results.append(random_results, ignore_index=True)
model_results
# Out:
#            Model  Accuracy  FalseNegRate    Recall  Precision  F1 Score
# 0   DecisionTree  0.999075      0.235294  0.764706   0.688742  0.724739
# 1  Random Forest  0.999614      0.183824  0.816176   0.932773  0.870588

# %%
import random
num = random.choice([x for x in range(1000)])

label = {0:'Non Fraud', 1:'Fraud'}

X_new =[ X_test.iloc[0,:]]
print(f'Prediction: {label[random_forest.predict(X_new)[0]]}')
# Out:
# Prediction: Fraud
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   "X does not have valid feature names, but"
